# %%
import pandas as pd
import numpy as np 
import plotly.express as px
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.graph_objects as go

# %%
df = pd.read_csv("World_economy.csv")
df.rename(columns = {"GDP_world":"GDP", 
                     "Inflation_world" : "Inflation",
                     "agriculture_percent": "Agriculture_Percentage",
                     "exp_education":"Expenditure_on_Education",
                     "health_exp":"Expenditure_on_Health",
                     "export":"Export",
                     "import":"Import",
                     "unemployment":"Unemployment"},inplace =True)
df["Net_trade"] = df.Export - df['Import']
df.head()
# Out:
#   Country Name Country Code  Year  Agriculture_Percentage  Ease_of_business  \
# 0  Afghanistan          AFG  2000               27.501127         40.717968
# 1  Afghanistan          AFG  2001               27.501127         40.717968
# 2  Afghanistan          AFG  2002               38.627892         40.717968
# 3  Afghanistan          AFG  2003               37.418855         40.717968
# 4  Afghanistan          AFG  2004               29.721067         40.717968
#
#    Exp_Edu_percent_of_GDP  Export           GDP  Exp_Health_percent_of_GDP  \
# 0               13.670101     NaN  1.415197e+10                  10.902580
# 1               13.670101     NaN  1.415197e+10                  10.902580
# 2               13.670101     NaN  3.854235e+09                   9.443391
# 3               13.670101     NaN  4.539497e+09                   8.941258
# 4               13.670101     NaN  5.220825e+09                   9.808474
#
#    Import  ...  Inflation  RnD  Service_percent  Unemployment  Population  \
# 0     NaN  ...    6.12462  NaN        48.302753         8.054  19542982.0
# 1     NaN  ...    6.12462  NaN        48.302753         8.040  19688632.0
# 2     NaN  ...    6.12462  NaN        36.151155         8.186  21000256.0
# 3     NaN  ...    6.12462  NaN        37.444804         8.122  22645130.0
# 4     NaN  ...    6.12462  NaN        41.110895         8.053  23553551.0
#
#    Continent_Name Exp_Edu_real_value  Exp_Health_real_value  Net_trade  \
# 0            Asia       1.934589e+09           1.542930e+09        NaN
# 1            Asia       1.934589e+09           1.542930e+09        NaN
# 2            Asia       5.268779e+08           3.639705e+08        NaN
# 3            Asia       6.205538e+08           4.058881e+08        NaN
# 4            Asia       7.136921e+08           5.120832e+08        NaN
#
#    GDP_Per_Cap
# 0   724.145910
# 1   718.788917
# 2   183.532775
# 3   200.462376
# 4   221.657662
#
# [5 rows x 21 columns]

# %% [markdown]
# ### GDP Race

# %%
gdp_data = df[df.GDP.isna()==False].groupby(["Continent_Name","Year"])["GDP"].sum().reset_index()
px.line(gdp_data, x = "Year", y = "GDP", color = "Continent_Name", height = 700,markers=True)

# %%
countries_data = df[(df["Continent_Name"] == "Asia")&(df.GDP.isna()==False)]

px.line(countries_data , x = "Year", y = "GDP", color = "Country Name",height = 700,
        markers=True)

# %%
choro_data = df[df.GDP.isna()==False].sort_values(["Year"])
px.choropleth(choro_data , locations ="Country Code", color = "GDP", 
              range_color=[0,3000000000000], width = 1400, height = 900,
               color_continuous_scale="Viridis",animation_frame="Year" )

# %%
df.columns
# Out:
# Index(['Country Name', 'Country Code', 'Year', 'Agriculture_Percentage',
#        'Ease_of_business', 'Exp_Edu_percent_of_GDP', 'Export', 'GDP',
#        'Exp_Health_percent_of_GDP', 'Import', 'Industry_percent', 'Inflation',
#        'RnD', 'Service_percent', 'Unemployment', 'Population',
#        'Continent_Name', 'Exp_Edu_real_value', 'Exp_Health_real_value',
#        'Net_trade', 'GDP_Per_Cap'],
#       dtype='object')

# %%
df["Country Name"].unique()[50:100]
# Out:
# array(['Cyprus', 'Czechia', 'Denmark', 'Djibouti', 'Dominica',
#        'Dominican Republic', 'Ecuador', 'Egypt, Arab Rep.', 'El Salvador',
#        'Equatorial Guinea', 'Eritrea', 'Estonia', 'Eswatini', 'Ethiopia',
#        'Faroe Islands', 'Fiji', 'Finland', 'France', 'French Polynesia',
#        'Gabon', 'Gambia, The', 'Georgia', 'Germany', 'Ghana', 'Gibraltar',
#        'Greece', 'Greenland', 'Grenada', 'Guam', 'Guatemala', 'Guinea',
#        'Guinea-Bissau', 'Guyana', 'Haiti', 'Honduras',
#        'Hong Kong SAR, China', 'Hungary', 'Iceland', 'India', 'Indonesia',
#        'Iran, Islamic Rep.', 'Iraq', 'Ireland', 'Isle of Man', 'Israel',
#        'Italy', 'Jamaica', 'Japan', 'Jordan', 'Kazakhstan'], dtype=object)
