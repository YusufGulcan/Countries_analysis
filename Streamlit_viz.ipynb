# %%
import pandas as pd
import numpy as np 
import plotly.express as px
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.graph_objects as go

# %%
df = pd.read_csv("World_economy.csv")
df.rename(columns = {"GDP_world":"GDP", 
                     "Inflation_world" : "Inflation",
                     "agriculture_percent": "Agriculture_Percentage",
                     "exp_education":"Expenditure_on_Education",
                     "health_exp":"Expenditure_on_Health",
                     "export":"Export",
                     "import":"Import",
                     "unemployment":"Unemployment"},inplace =True)
df["Net_trade"] = df.Export - df['Import']
df.head()
# Out:
#   Country Name Country Code  Year  Agriculture_Percentage  Ease_of_business  \
# 0  Afghanistan          AFG  2000                     NaN               NaN
# 1  Afghanistan          AFG  2001                     NaN               NaN
# 2  Afghanistan          AFG  2002               38.627892               NaN
# 3  Afghanistan          AFG  2003               37.418855               NaN
# 4  Afghanistan          AFG  2004               29.721067               NaN
#
#    Expenditure_on_Education  Export           GDP  Expenditure_on_Health  \
# 0                       NaN     NaN           NaN                    NaN
# 1                       NaN     NaN           NaN                    NaN
# 2                       NaN     NaN  3.854235e+09               9.443391
# 3                       NaN     NaN  4.539497e+09               8.941258
# 4                       NaN     NaN  5.220825e+09               9.808474
#
#    Import  Industry_percent  Inflation  RnD  Service_percent  Unemployment  \
# 0     NaN               NaN        NaN  NaN              NaN         8.054
# 1     NaN               NaN        NaN  NaN              NaN         8.040
# 2     NaN         23.810127        NaN  NaN        36.151155         8.186
# 3     NaN         22.710864        NaN  NaN        37.444804         8.122
# 4     NaN         26.226790        NaN  NaN        41.110895         8.053
#
#    Population Continent_Name  Net_trade
# 0  19542982.0           Asia        NaN
# 1  19688632.0           Asia        NaN
# 2  21000256.0           Asia        NaN
# 3  22645130.0           Asia        NaN
# 4  23553551.0           Asia        NaN

# %% [markdown]
# ### GDP Race

# %%
gdp_data = df[df.GDP.isna()==False].groupby(["Continent_Name","Year"])["GDP"].sum().reset_index()
px.line(gdp_data, x = "Year", y = "GDP", color = "Continent_Name")

# %%
countries_data = df[(df["Continent_Name"] == "Asia")&(df.GDP.isna()==False)]

px.line(countries_data , x = "Year", y = "GDP", color = "Country Name",
        markers=True)

# %%
choro_data = df[df.GDP.isna()==False].sort_values(["Year"])
px.choropleth(choro_data , locations ="Country Code", color = "GDP", 
              range_color=[0,3000000000000], width = 1400, height = 900,
               color_continuous_scale="Viridis",animation_frame="Year" )

# %%
df.columns
# Out:
# Index(['Country Name', 'Country Code', 'Year', 'Agriculture_Percentage',
#        'Ease_of_business', 'Expenditure_on_Education', 'Export', 'GDP',
#        'Expenditure_on_Health', 'Import', 'Industry_percent', 'Inflation',
#        'RnD', 'Service_percent', 'Unemployment', 'Population',
#        'Continent_Name', 'Net_trade'],
#       dtype='object')

# %%
df["Country Name"].unique()[50:100]
# Out:
# array(['Cyprus', 'Czechia', 'Denmark', 'Djibouti', 'Dominica',
#        'Dominican Republic', 'Ecuador', 'Egypt, Arab Rep.', 'El Salvador',
#        'Equatorial Guinea', 'Eritrea', 'Estonia', 'Eswatini', 'Ethiopia',
#        'Faroe Islands', 'Fiji', 'Finland', 'France', 'French Polynesia',
#        'Gabon', 'Gambia, The', 'Georgia', 'Germany', 'Ghana', 'Gibraltar',
#        'Greece', 'Greenland', 'Grenada', 'Guam', 'Guatemala', 'Guinea',
#        'Guinea-Bissau', 'Guyana', 'Haiti', 'Honduras',
#        'Hong Kong SAR, China', 'Hungary', 'Iceland', 'India', 'Indonesia',
#        'Iran, Islamic Rep.', 'Iraq', 'Ireland', 'Isle of Man', 'Israel',
#        'Italy', 'Jamaica', 'Japan', 'Jordan', 'Kazakhstan'], dtype=object)

# %%
cc = list(set(cc))

# %%
tt = set(cc)
tt
# Out:
# {'United States', 'Yemen, Rep.'}

# %%
tt[-1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\yusuf\OneDrive\Documents\Data Science Projects\World Economy\Streamlit_viz.ipynb Cell 11 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/yusuf/OneDrive/Documents/Data%20Science%20Projects/World%20Economy/Streamlit_viz.ipynb#X14sZmlsZQ%3D%3D?line=0'>1</a> tt[-1]
#
# TypeError: 'set' object is not subscriptable

# %%
df
# Out:
#      Country Name Country Code  Year  Agriculture_Percentage  \
# 0     Afghanistan          AFG  2000                     NaN
# 1     Afghanistan          AFG  2001                     NaN
# 2     Afghanistan          AFG  2002               38.627892
# 3     Afghanistan          AFG  2003               37.418855
# 4     Afghanistan          AFG  2004               29.721067
# ...           ...          ...   ...                     ...
# 5101     Zimbabwe          ZWE  2018                7.319375
# 5102     Zimbabwe          ZWE  2019                9.819262
# 5103     Zimbabwe          ZWE  2020                8.772859
# 5104     Zimbabwe          ZWE  2021                8.849899
# 5105     Zimbabwe          ZWE  2022                     NaN
#
#       Ease_of_business  Expenditure_on_Education     Export           GDP  \
# 0                  NaN                       NaN        NaN           NaN
# 1                  NaN                       NaN        NaN           NaN
# 2                  NaN                       NaN        NaN  3.854235e+09
# 3                  NaN                       NaN        NaN  4.539497e+09
# 4                  NaN                       NaN        NaN  5.220825e+09
# ...                ...                       ...        ...           ...
# 5101          50.50998                 19.039841  26.163973  3.415607e+10
# 5102          54.46935                       NaN  27.163459  2.183223e+10
# 5103               NaN                 15.666611  25.917014  2.150970e+10
# 5104               NaN                       NaN  25.411446  2.837124e+10
# 5105               NaN                       NaN        NaN  2.067806e+10
#
#       Expenditure_on_Health     Import  Industry_percent   Inflation  RnD  \
# 0                       NaN        NaN               NaN         NaN  NaN
# 1                       NaN        NaN               NaN         NaN  NaN
# 2                  9.443391        NaN         23.810127         NaN  NaN
# 3                  8.941258        NaN         22.710864         NaN  NaN
# 4                  9.808474        NaN         26.226790         NaN  NaN
# ...                     ...        ...               ...         ...  ...
# 5101               4.670418  28.386297         31.037898   10.618866  NaN
# 5102               3.659765  25.524111         32.025947  255.304991  NaN
# 5103               3.425581  28.733547         32.767517  557.201817  NaN
# 5104                    NaN  30.901234         28.805586   98.546105  NaN
# 5105                    NaN        NaN               NaN  104.705171  NaN
#
#       Service_percent  Unemployment  Population Continent_Name  Net_trade
# 0                 NaN         8.054  19542982.0           Asia        NaN
# 1                 NaN         8.040  19688632.0           Asia        NaN
# 2           36.151155         8.186  21000256.0           Asia        NaN
# 3           37.444804         8.122  22645130.0           Asia        NaN
# 4           41.110895         8.053  23553551.0           Asia        NaN
# ...               ...           ...         ...            ...        ...
# 5101        55.984768         6.784  15052184.0         Africa  -2.222324
# 5102        52.677299         7.370  15354608.0         Africa   1.639348
# 5103        52.892574         7.898  15669666.0         Africa  -2.816533
# 5104        56.639870         8.067  15993524.0         Africa  -5.489788
# 5105              NaN         7.945  16320537.0         Africa        NaN
#
# [5106 rows x 18 columns]
